# %% [markdown]
# # 13 - Word2Vec from Scratch (Efficient)
#
# Goal: Implement Word2Vec from scratch on Spanish text
#
# Run with: conda activate tfenv

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import plotly.express as px
import pandas as pd
import time

print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow version: 2.21.0

# %%
# Large Spanish text (combined from multiple sources)
text = """
El mercado de tecnologías de la información ha experimentado un crecimiento sin precedentes en los últimos años. Las empresas invierten cada vez más en soluciones digitales para mejorar su eficiencia y competitividad. La inteligencia artificial se ha convertido en una herramienta fundamental para automatizar procesos y tomar decisiones basadas en datos. Los profesionales del sector tecnológico buscan constantemente actualizar sus habilidades para mantenerse al día con las últimas tendencias. El aprendizaje automático permite a las máquinas mejorar su rendimiento a través de la experiencia sin ser programadas explícitamente. Las redes neuronales profundas han revolucionado campos como el reconocimiento de voz y la visión por computadora. El procesamiento del lenguaje natural ha avanzado significativamente permitiendo a las máquinas entender y generar texto de manera más natural. Los modelos de lenguaje grandes como GPT han demostrado capacidades sorprendentes en múltiples tareas. La seguridad cibernética se ha vuelto crítica ya que las amenazas digitales evolucionan constantemente. Las empresas necesitan proteger sus datos y sistemas de ataques maliciosos. La computación en la nube ofrece flexibilidad y escalabilidad para las organizaciones. Los servicios web permiten a las aplicaciones comunicarse e intercambiar información de manera eficiente. Las bases de datos almacenan información estructurada que puede ser consultada y analizada. Los desarrolladores utilizan lenguajes de programación como Python Java y JavaScript para crear soluciones innovadoras. Los frameworks facilitan el desarrollo de aplicaciones web y móviles con interfaces modernas. La metodología ágil promueve la colaboración y la entrega iterativa de valor al cliente. Los equipos de desarrollo trabajan de manera colaborativa utilizando herramientas de control de versiones. La documentación técnica es esencial para mantener y evolucionar los sistemas de información. Las pruebas automatizadas garantizan la calidad del software antes de su despliegue. Los contenedores permiten打包 y desplegar aplicaciones de manera consistente en diferentes entornos. La integración continua automatiza el proceso de construcción y verificación del código. El despliegue continuo facilita la entrega rápida de nuevas funcionalidades a producción. El monitoreo de aplicaciones permite detectar y resolver problemas de manera proactiva. Las métricas de rendimiento ayudan a identificar cuellos de botella y oportunidades de optimización. La arquitectura de microservicios permite escalar componentes de manera independiente. Las API RESTful son el estándar para la comunicación entre servicios web. El formato JSON se utiliza ampliamente para intercambio de datos por su legibilidad y flexibilidad. Los protocolos de seguridad como HTTPS protegen la información sensible durante la transmisión. La autenticación y autorización controlan el acceso a los recursos del sistema. Los tokens JWT permiten mantener sesiones de usuario de manera stateless. Las bases de datos relacionales ofrecen consistencia y integridad de datos mediante transacciones. Las bases de datos NoSQL proporcionan escalabilidad horizontal para manejar grandes volúmenes de datos. El caché mejora el rendimiento almacenando información frecuentemente accedida. Los message brokers facilitan la comunicación asíncrona entre componentes. Los patrones de diseño ofrecen soluciones probadas a problemas comunes de desarrollo. La inversión en tecnología genera retorno positivo para las organizaciones que la implementan correctamente. La transformación digital es imperativa para las empresas que buscan mantenerse competitivas en el mercado actual. Los profesionales deben continuar aprendiendo nuevas tecnologías y metodologías para agregar valor a sus equipos. La innovación tecnológica continúa transformando industrias y creando nuevas oportunidades de negocio. Los datos son el nuevo petróleo y su análisis correcto puede revelar insights valiosos para la toma de decisiones. La visualización de datos facilita la comprensión de información compleja para usuarios no técnicos. Los dashboards interactivos permiten monitorear indicadores clave de desempeño en tiempo real. Los modelos predictivos utilizan datos históricos para anticipar eventos futuros con cierto grado de precisión. Los sistemas de recomendación personalizan la experiencia del usuario basándose en sus preferencias y comportamiento. La automatización de procesos robóticos elimina tareas repetitivas permitiendo a los empleados enfocarse en actividades de mayor valor. La tecnología blockchain ofrece transparencia y seguridad para registros inmutables. Los contratos inteligentes automatizan la ejecución de acuerdos entre partes sin necesidad de intermediarios. La realidad aumentada y virtual están transformando la manera de interactuar con la información digital. Los dispositivos inteligentes del internet de las cosas generan datos que pueden ser analizados para optimizar procesos. Las redes 5G permiten conectividad ultra rápida habilitando nuevas aplicaciones y servicios. La computación cuántica promete resolver problemas actualmente intratables para las computadoras clásicas. Los principios de diseño centrado en el usuario garantizan que los productos tecnológicos sean intuitivos y accesibles. La accesibilidad web asegura que las personas con discapacidades puedan utilizar las tecnologías de la información. Las regulaciones de protección de datos como GDPR requieren prácticas responsables en el manejo de información personal. La ética en inteligencia artificial es un tema cada vez más relevante para desarrollar sistemas justos y equitativos. La sostenibilidad tecnológica promote el desarrollo de soluciones que minimizan el impacto ambiental. Los estándares de calidad aseguran la confiabilidad y seguridad de los sistemas tecnológicos. Las certificaciones profesionales validan las competencias técnicas de los trabajadores del sector. Las comunidades open source colaboran en el desarrollo de software que benefician a toda la industria. Los eventos tecnológicos permiten compartir conocimiento y establecer contactos profesionales. Las startup tecnológicas disruptan modelos de negocio tradicionales con soluciones innovadoras. Las incubadoras y aceleradoras apoyan el crecimiento de empresas emergentes con potencial. La inversión de riesgo financia proyectos de alta tecnología con perspectivas de alto crecimiento. El emprendedurismo tecnológico crea empleo y contribuye al desarrollo económico de las regiones. La educación tecnológica prepara a las nuevas generaciones para los empleos del futuro. Los bootcamps ofrecen formación intensiva para adquirir habilidades técnicas en короткий plazo. Las plataformas de aprendizaje en línea democratizan el acceso a la educación de calidad. Los mentores guían a los desarrolladores principiantes en su camino profesional. La red de contactos profesionales es fundamental para el desarrollo de carrera en tecnología. El equilibrio entre vida laboral y personal es importante para evitar el agotamiento profesional. La diversidad e inclusión en tecnología generan equipos más creativos y resilientes. El liderazgo técnico inspire y guíe a los equipos hacia la excelencia en la ejecución de proyectos. La comunicación efectiva es clave para alinear a los equipos autour de objetivos comunes. La gestión de proyectos ágil permite responder rápidamente a los cambios del mercado. La estimación realista de tiempos y recursos evita retrasos y costos inesperados. La gestión de riesgos identifica y mitiga potenciales problemas antes de que ocurran. La mejora continua busca optimizar procesos y prácticas de manera sistemática. Los indicadores de des
medicamentos. Los sensores del internet de las cosas monitorean salud continuamente. Los sistemas predictivos anticipan epidemias antes de que se propaguen. La tecnología espacial explora nuevos mundos y expande comprensión humana. Los satélites monitorizan cambio climático y recursos naturales. La impresión 3D fabrica objetos desde modelos digitales. La realidad aumentada superpone información digital al mundo físico. Los gemelos digitales simulan sistemas complejos para optimización. La computación cuántica resolverá problemas actualmente imposibles. Los materiales avanzados enable nuevas aplicaciones en todas las industrias. La nanotecnología manipula materia a escala molecular. La impresión biológico crea tejidos y órganos artificiales. Los drones realizan entregas y mediciones en zonas peligrosas. Los robots industriales automatizan tareas peligrosas y repetitivas. La ciberseguridad proteje infraestructura crítica de ataques. La criptografía asegura comunicaciones y transacciones seguras. Los identidades digitales simplifican acceso a servicios. La privacidad de datos protege información personal de los usuarios. Los derechos digitales aseguran protección de personas en el mundo virtual. Las regulaciones tecnológicas equilibran innovación con protección social. Los estándares técnicos interoperabilidad entre sistemas. Los protocolos de internet connect dispositivos globally. Las arquitecturas de software definen cómo sistemas funcionan. Los patrones de diseño solving problemas comunes de desarrollo. Las metodologías ágiles adaptan procesos a necesidades cambiantes. Los principios SOLID guían diseño de código mantenible. Las pruebas automatizadas ensure calidad del software. El monitoreo de producción detecta problemas rápidamente. Los logs de aplicación registran actividades para debugging. Las métricas de negocio tracking progresso hacia objetivos organizacionales. Los dashboards ejecutivas presentan información estratégica. La analítica de datos revela patrones ocultos en información. Los modelos predictivos anticipan tendencias futuras. Los sistemas de recomendación personalizan experiencias de usuarios. La segmentación de clientes permite marketing más efectivo. La optimización de procesos mejora eficiencia operativa. La automatización reduce costos y errores humanos. La integración de sistemas unifica información dispar. La migración a la nube reduce infraestructura propia. Los servicios administrados externalizan operaciones técnicas. La DevOps cultura rompe silos entre desarrollo y operaciones. La infraestructura como código automatiza despliegues de entornos. Los contenedores docker facilitan empaquetado de aplicaciones. Los orquestadores kubernetes gestionan cargas de trabajo distribuidas. Los service meshes manejar comunicación entre microservicios. Las arquitecturas serverless reducen costos por uso. Los edge computing procesa datos cerca de su origen. Los sistemas en tiempo real responden inmediatamente a eventos. Los flujos de datos continuos procesan información constantemente. Los lagos de datos almacenan información sin estructurar para análisis posterior. Los data warehouses consolidan información para reportes empresariales. Los data marts especializan datos para departamentos específicos. Las capas de presentación muestran información a usuarios finales. Las APIs exponen funcionalidad para consumo externo. Los servicios backend implementan lógica de negocio compleja. Las bases de datos persiste información estructurada. Los caches aceleran acceso a datos frecuentes. Las colas de mensajes desacoplan componentes. Los workers procesan tareas asíncronamente. Losスケジュール jobs ejecutan procesos programados. Los webhooks notifican eventos a sistemas externos. Los filtros y validaciones ensures datos correctness. Los transformers convierten datos entre formatos. Los enrichers agregan información contextual. Los routers dirigen flujo según reglas establecidas. Los aggregators combinan múltiples fuentes. Los sinks escriben a destinos finales. Los pipelines orquestan flujo completo de datos. Los schedulers gestionan temporización de procesos. Los monitors alertan sobre anomalías. Los dashboards visualizan estado de sistemas. Los logs centralizados facilitan debugging. Los tracing distribuidos identifican problemas en arquitecturas complejas. Los metrics收集 información cuantitativa de rendimiento. Los alertas notifican condiciones que requieren atención. Los runbooks documentan procedimientos de respuesta a incidentes. Los post-mortems analizan causas raíz de problemas. Los Continuous improvement procesos optimizan operaciones. Los SLAs establecen compromisos de servicio. Los SLOs definen objetivos específicos de rendimiento. Los error budgets permiten equilibrar velocidad y estabilidad. Los feature flags controlan релизы sin despliegues. Los canary releases prueban cambios con subconjunto de usuarios. Los blue green deployments permiten rollback instantáneo. Los dark launches revelan features gradualmente. Los A/B tests comparan versiones alternativas. Los experimentos estadísticos validan hipótesis de negocio. Los feature prioritization alinean desarrollo con valor de negocio. Los roadmaps planifican evolución de productos. Los backlogs priorizan trabajo pendiente. Los sprints entregan valor incrementalmente. Los standups sincronizan progreso del equipo. Los planning sessions estiman esfuerzo y planifican trabajo. Los refinements aclaran requisitos y criterios de aceptación. Los demos muestran progreso a stakeholders. Los retrospectives identifican oportunidades de mejora. Los one-on-ones desarrollan profesionalmente a cada miembro del equipo. Los Career plans guían desarrollo a largo plazo. Los 个人 OKRs alinean objetivos individuales con organizacionales. Los recognizing achievements motivate desempeño excepcional. Los promoting internally разви talento del propio equipo. Los surrounding with talented people raises nivel colectivo. Los fostering innovation crea ambiente propicio a creatividad. Los challenging technical problems develops habilidades de resolución. Los mentoring others solidify conocimiento propio. Los speaking at conferences shared conocimiento públicamente. Los writing technical articles educa a la comunidad. Los contributing to open source give back to la comunidad. Los building products que解决 real problems es la meta final. Los delivering value to users justify todo el esfuerzo técnico. Los measuring impact cuantifica contribución al negocio. Los iterating based on feedback mejora continuamente. Los collaborating across functions rompe silos organizacionales. Los influencing strategy aporta perspectiva técnica a decisiones de negocio. Los leading by example modelo el comportamiento deseado. Los empowering others develop liderazgo en otros. Los creating systems that scale handle crecimiento exitoso. Los solving problems that matter genera impacto significativo. Los building technology that helps people improve quality de vida. Los shaping future de la industria through innovación. Los leaving legacy de conocimiento para siguientes generaciones. Los making difference in world through tecnología. Los pursuing mastery in craft de desarrollo de software. Los achieving flow state through coding desafiante y satisfactorio. Los loving what you do hace el trabajo más significativo. Los finding meaning en el impacto positivo de la tecnología. Los celebrating successes del equipo y organizaciones. Los learning from failures view as oportunidades de mejora. Los staying curious about new technologies expands capacidades. Los staying humble despite expertise mantiene apertura a nuevos aprendizajes. Los staying hungry for improvement drive crecimiento continuo. Los being kind to colleagues create ambiente de trabajo positivo. Los being helpful to teammates support colaboración efectiva. Los being patient with learners guía a principiantes con empatía. Los being respectful of different perspectives enriquece decisiones. Los being inclusive of underrepresented groups fosters diversidad. Los being ethical in work guía decisiones correctas. Los being accountable for commitments genera confianza. Los being transparent about challenges facilita apoyo. Los being reliable in deliveries establece credibilidad. Los being adaptable to change flex to new requirements. Los being resilient under pressure mantiene desempeño en crisis. Los being optimistic about future inspira a otros. Los being grateful for opportunities aprecia cada experiencia. Los being present in momento actual disfruta el viaje. Los being mindful of wellbeing mantiene equilibrio saludable. Los being sustainable in pace evita burnout. Los being creative in solutions abord challenges differently. Los being pragmatic in choices prioriza impacto sobre complejidad. Los being bold in experiments prueba cosas nuevas. Los being careful in implementations garantiza calidad. Los being efficient in execution optimiza recursos. Los being effective in outcomes genera resultados reales. Los being valuable to organization justifica existencia. Los being impactful to society crea cambio positivo. Los being meaningful to users sirve necesidades reales. Los being delightful to customers supera expectativas. Los being trusted by colleagues establece relaciones sólidas. Los being respected by peers reconoce expertise. Los being admired by juniors inspire desarrollo. Los being recognized by industry alcanza visibilidad profesional. Los being satisfied with work proporciona realización personal. Los being proud of contributions valora esfuerzo invertido. Los being motivated to continue drives next desafío. Los being ready for next adventure ожидает nuevas oportunidades.
"""

# Process text
words = text.lower().split()
words = [w.strip('.,;:!?()[]"\'-0123456789') for w in words]
words = [w for w in words if len(w) > 2]

print(f"Total words: {len(words)}")
print(f"Sample: {words[:20]}")
# Out:
# Total words: 2721
# Sample: ['mercado', 'tecnologías', 'información', 'experimentado', 'crecimiento', 'sin', 'precedentes', 'los', 'últimos', 'años', 'las', 'empresas', 'invierten', 'cada', 'vez', 'más', 'soluciones', 'digitales', 'para', 'mejorar']

# %%
# Build vocabulary
from collections import Counter
word_counts = Counter(words)
vocab = [w for w, c in word_counts.items() if c >= 3]

text_vocab = {word: idx for idx, word in enumerate(vocab)}
text_vocab_size = len(text_vocab)
text_embed_dim = 64

print(f"Vocabulary: {text_vocab_size} words")
# Out:
# Vocabulary: 178 words

# %%
# Create training pairs (Skip-gram)
def create_pairs(words, window=2):
    pairs = []
    for i, word in enumerate(words):
        if word not in text_vocab:
            continue
        for j in range(max(0, i - window), min(len(words), i + window + 1)):
            if i != j and words[j] in text_vocab:
                pairs.append((text_vocab[word], text_vocab[words[j]]))
    return pairs

pairs = create_pairs(words)
train_words = np.array([p[0] for p in pairs], dtype=np.int32)
train_context = np.array([p[1] for p in pairs], dtype=np.int32)
print(f"Training pairs: {len(pairs)}")
# Out:
# Training pairs: 2482

# %%
# Word2Vec from scratch using Keras
embedding_layer = layers.Embedding(
    input_dim=text_vocab_size,
    output_dim=text_embed_dim,
    name='embedding'
)

model = keras.Sequential([
    embedding_layer,
    layers.Flatten(),
    layers.Dense(text_vocab_size, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.02),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Word2Vec model ready!")
model.summary()
# Out:
# Word2Vec model ready!
# E0000 00:00:1779035453.993858    1325 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1779035454.044358    1325 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ...

# %%
# Efficient training with tf.data
train_ds = tf.data.Dataset.from_tensor_slices((train_words, train_context))
train_ds = train_ds.shuffle(buffer_size=len(train_words)).batch(512).prefetch(tf.data.AUTOTUNE)

print("Training Word2Vec...")
start = time.time()

history = model.fit(
    train_ds,
    epochs=15,
    verbose=1
)

print(f"Training time: {time.time() - start:.2f}s")
# Out:
# Training Word2Vec...
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.0669 - loss: 5.1325
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1741 - loss: 4.7944
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1817 - loss: 4.3820
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1853 - loss: 4.0481
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1857 - loss: 3.7896
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1809 - loss: 3.5677
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1841 - loss: 3.3747
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1801 - loss: 3.2215
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1821 - loss: 3.0997
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1797 - loss: 3.0054
# Training time: 2.32s

# %%
# Get embeddings
embeddings = embedding_layer.get_weights()[0]
print(f"Embeddings shape: {embeddings.shape}")

# Find similar words
from numpy.linalg import norm

def cosine_similarity(a, b):
    return np.dot(a, b) / (norm(a) * norm(b) + 1e-8)

def find_similar(word, top_n=5):
    if word not in text_vocab:
        return []
    word_idx = text_vocab[word]
    word_emb = embeddings[word_idx]
    
    similarities = []
    for w, idx in text_vocab.items():
        if w != word:
            sim = cosine_similarity(word_emb, embeddings[idx])
            similarities.append((w, sim))
    
    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]

print("=== Similar Words ===")
test_words = ['tecnología', 'datos', 'desarrollo', 'empresas', 'aprendizaje', 'software']
for word in test_words:
    if word in text_vocab:
        similar = find_similar(word)
        print(f"'{word}' -> {[(w, f'{s:.3f}') for w, s in similar]}")
# Out:
# Embeddings shape: (178, 64)
# === Similar Words ===
# 'tecnología' -> [('impacto', '0.624'), ('equipos', '0.437'), ('web', '0.432'), ('guía', '0.426'), ('valor', '0.419')]
# 'datos' -> [('sin', '0.540'), ('mercado', '0.482'), ('flexibilidad', '0.467'), ('seguridad', '0.445'), ('análisis', '0.434')]
# 'desarrollo' -> [('diversidad', '0.532'), ('profesional', '0.473'), ('arquitecturas', '0.454'), ('proyectos', '0.450'), ('reales', '0.410')]
# 'empresas' -> [('información', '0.538'), ('organizaciones', '0.521'), ('técnica', '0.498'), ('actividades', '0.461'), ('herramientas', '0.438')]
# 'aprendizaje' -> [('capacidades', '0.472'), ('continuo', '0.390'), ('comunidades', '0.351'), ('profesional', '0.338'), ('plataformas', '0.326')]
# 'software' -> [('nuevos', '0.587'), ('conocimiento', '0.576'), ('organizaciones', '0.565'), ('global', '0.522'), ('inteligentes', '0.514')]

# %%
# Visualize in 3D with PCA
from sklearn.decomposition import PCA

top_words = [w for w, c in word_counts.most_common(200) if w in text_vocab]
top_indices = [text_vocab[w] for w in top_words]
top_embeddings = embeddings[top_indices]

pca = PCA(n_components=3)
embeddings_3d = pca.fit_transform(top_embeddings)

df = pd.DataFrame(embeddings_3d, columns=['x', 'y', 'z'])
df['word'] = top_words

fig = px.scatter_3d(df, x='x', y='y', z='z', text='word',
                 title='Word Embeddings (PCA 3D) - Top 200 words')
fig.update_traces(marker=dict(size=6), textposition='top center')
fig.show()
